# %% [markdown]
# # Web scraping application with Python using Requests and BeautifulSoup
#
# ### Extraction of climate data located in tables on web pages

# %% [markdown]
# <img src = './img/ws_requests_beautifulsoup.jpg' width = 800>

# %% [markdown]
# ### **Consideraciones legales y éticas**
#
# Esta publicación no trata sobre cómo extraer datos de una página web con fines ilegales.
# Hay que asegurarse de tener permiso antes de extraer ciertos tipos de datos que puede violar los términos del servicio o incluso regulaciones legales:
#
# - Revise los términos de uso de la página web en relación a los permisos de extracción de datos.
# - Priorice el uso de las APIs, si están disponibles, ya que proporcionan acceso legal a los datos.
# - Póngase en contacto directamente con el propietario de la página web para comprobar el permiso de extracción de datos.

# %% [markdown]
# ### **Introducción**
#
# En este proyecto veremos cómo se pueden extraer datos de una página web que contiene información climática en diversas estaciones meteorológicas en toda España, haciendo uso de **requests** y **BeautifulSoup**.
#
# En concreto, la página web es de "eltiempo.es" y me centraré en la localidad de A Coruña, obteniendo una tabla de valores climáticos para los próximos 9 días.

# %% [markdown]
# ### **Instalación de paquetes**
#
# A continuación se muestran las librerías necesarias para la ejecución del código.
#
# - ipykernel:  kernel de Jupyter necesario para ejecutar Python
# - tqdm: herramienta útil para crear barras de progeso en bucles
# - joblib: biblioteca que permite la serialización de objetos Python.
# - pandas: biblioteca escrita sobre Numpy para manipulación y análisis de datos
# - request: librería que permite hacer peticiones HTTP
# - bs4: librería BeautifulSoup que permite extraer datos de HTML y XML
#
#
# Ejecutamos en la terminal el siguiente código:
#
# `pip install ipykernel tqdm joblib pandas requests bs4`

# %% [markdown]
# ### **Importación de librerías**

# %%
import os # proporciona funcionalidad del sistema operativo
import datetime # manipulación de fechas y horas
import pandas as pd # manipulación y análisis de datos
import requests # realizar peticiones HTTP
from bs4 import BeautifulSoup # extraer datos de HTML y XML
from csv import writer # crea un objeto para escribir datos en archivos csv
from csv import DictWriter # crea un objeto para escribir datos en archivos csv donde cada fila es un diccionario

# %% [markdown]
# ### **Funciones útiles**
#
# Creación de funciones que utilizaremos más adelante para generar un archivo en formato csv y almacenar datos en él.

# %%
def append_header_as_row(file_name, field_names):
    """ 
    Abre un csv y agrega los nombres de las columnas (headers).
    Args: 
    file_name: nombre del archivo que abrimos,
    field_names: headers que añadimos como una lista.
    """

    # Compruebo si el archivo existe
    file_existe = os.path.isfile(file_name)
    
    # Si existe, se elimina
    if file_existe:
        os.remove(file_name)
        print(f'Archivo {file_name} eliminado.')       

    # Abre el archivo en modo 'append'
    with open(file_name, 'a+', newline='') as write_obj:
        # Crea un objeto 'writer' desde el módulo csv
        dict_writer = DictWriter(write_obj, fieldnames=field_names)
        # Añade la cabecera al objeto
        dict_writer.writeheader() 
        
def append_dict_as_row(file_name, dict_of_elem, field_names):
    """ 
    Abre un csv y agrega una fila en forma de diccionario en el csv.
    Args:
    file_name: nombre del csv que abrimos,
    dict_of_elem: diccionario con los elementos de la fila que se va a añadir al final del csv,
    field_names: nombres de las columnas (headers) en forma de lista.
    """

    # Abre el archivo en modo 'append'
    with open(file_name, 'a+', newline='') as write_obj:
        # Crea un objeto 'writer' desde el módulo csv
        dict_writer = DictWriter(write_obj, fieldnames=field_names)
        #  Añade un diccionario de filas al csv
        dict_writer.writerow(dict_of_elem)

# %% [markdown]
# ### **Solicitud GET a la URL y obtención de los datos HTML**

# %%
# Definición de la url
keyword = 'a-coruna' # poner la localidad deseada
url = 'https://www.eltiempo.es/' + keyword +'.html'

# Solicitud GET a la url y respuesta HTML con BeautifulSoup
print('[TASK] Enviando petición GET para obtener los datos...')
page = requests.get(url)
content = page.content
soup = BeautifulSoup(content, 'html.parser')

# función prettify() para que la estructura del html se vea mejor
print(soup.prettify())
print('[OK] Respuesta HTTP recibida correctamente!')
# Out:
# [TASK] Enviando petición GET para obtener los datos...
# <!DOCTYPE html>
# <html lang="es-es">
#  <head>
#   <meta charset="utf-8"/>
#   <!-- Always force latest IE rendering engine or request Chrome Frame -->
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport">
#    <meta content="yes" name="apple-mobile-web-app-capable">
#     <!-- Use title if it's in the page YAML frontmatter -->
#     <title>
#      El Tiempo en A Coruña, A Coruña - 14 días
#     </title>
#     <meta content="A Coruña, A Coruña, España" name="locality"/>
#     <meta content="El Tiempo en A Coruña, A Coruña para los próximos 14 días, previsión actualizada del tiempo. Temperaturas, probabilidad de lluvias y velocidad del viento." name="description"/>
#     <meta content="El Tiempo en A Coruña, A Coruña para los próximos 14 días, previsión actualizada del tiempo. Temperaturas, probabilidad de lluvias y velocidad del viento." property="og:description"/>
#     <meta content="El Tiempo en A Coruña, A Coruña para los próximos 14 días, previsión actualizada del tiempo. Temperaturas, probabilidad de lluvias y velocidad del viento." name="twitter:description"/>
#     <meta content="el tiempo en A Coruña, tiempo A Coruña, eltiempo A Coruña, el tiempo hoy A Coruña, el tiempo mañana A Coruña, lluvia A Coruña, viento A Coruña, máximas A Coruña, mínimas A Coruña, previsión meteorológica A Coruña, predicción meteorológica A Coruña" name="keywords"/>
#     <meta content="A Coruña, A Coruña, España" name="locality"/>
#     <link href="https://www.eltiempo.es/a-coruna.html" rel="canonical"/>
#     <meta content="https://cdns3.eltiempo.es/eltiempo/opengraph/fb_share_560x292.jpg" property="og:image"/>
#     <meta content="560" property="og:image:width"/>
#     <meta content="292" property="og:image:height"/>
#     <meta content="https://cdns3.eltiempo.es/eltiempo/opengraph/fb_share_350x350.jpg" property="og:image"/>
#     <meta content="350" property="og:image:width"/>
#     <meta content="350" property="og:image:height"/>
#     <meta content="https://cdns3.eltiempo.es/eltiempo/opengraph/twitter_share_120x120.jpg" property="og:image"/>
#     <meta content="120" property="og:image:width"/>
#     <meta content="120" property="og:image:height"/>
#     <link as="style" href="https://cdn.eltiempo.es/dist/font_faces.2c05e5d4078e9b6b8fc9dad64409ad0b.css" rel="stylesheet preload"/>
#     <style>
#      /* '/dist/critical.css' */
# .meteo{speak:none;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;box-sizing:content-box;display:inline-block;font-family:meteo;font-style:normal;font-variant:normal;font-weight:400;line-height:1}.meteo-cloud-01:before{content:""}.meteo-cloud-02:before{content:""}.meteo-cloud-03:before{content:""}.meteo-cloud-04:before{content:""}.meteo-cloud-05:before{content:""}.meteo-cloud-06:before{content:""}.meteo-drop-00:before{content:""}.meteo-drop-01:before{content:""}.meteo-drop-02:before{content:""}.meteo-drop-03:before{content:""}.meteo-drop-04:before{content:""}.meteo-drop-05:before{content:""}.meteo-drop-06:before{content:""}.meteo-umbrella-01:before{content:""}.meteo-umbrella-02:before{content:""}.meteo-umbrella-03:before{content:""}.meteo-umbrella-04:before{content:""}.meteo-umbrella-05:before{content:""}.meteo-uv-01:before{content:""}.meteo-uv-02:before{content:""}.meteo-uv-03:before{content:""}.meteo-uv-04:before{content:""}.meteo-uv-05:before{content:""}.beach{speak:none;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;box-sizing:content-box;display:inline-block;font-family:eltiempo-beaches;font-style:normal;font-variant:normal;font-weight:400;line-height:1}.beach-blue-flag:before{content:""}.beach-access:before{content:""}.beach-handicapped:before{content:""}.beach-signal:before{content:""}.beach-rent-hammock:before{content:""}.beach-rent-boat:before{content:""}.beach-rent-umbrella:before{content:""}.beach-width:before{content:""}.beach-parking:before{content:""}.beach-restroom:before{content:""}.beach-bus:before{content:""}.beach-swim:before{content:""}.beach-club-boat:before{content:""}.beach-ground:before{content:""}.beach-direction:before{content:""}.beach-distant:before{content:""}.beach-shower:before{content:""}.beach-drinks:before{content:""}.beach-restaurant:before{content:""}.beach-city:before{content:""}.beach-hospital:before{content:""}.beach-feet-shower:before{content:""}.beach-clean:before{content:""}.beach-length:before{content:""}.beach-nudist:before{content:""}.beach-crowd:before{content:""}.beach-trash-can:before{content:""}.beach-trees:before{content:""}.beach-medical:before{content:""}.beach-phone:before{content:""}.beach-sand:before{content:""}.beach-underwater:before{content:""}.beach-snorkel:before{content:""}.beach-natural-reserve:before{content:""}.esqui{speak:none;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;box-sizing:content-box;display:inline-block;font-family:eltiempo-esqui;font-style:normal;font-variant:normal;font-weight:400;line-height:1}.esqui-snow-quality:before{content:""}.esqui-snow-height:before{content:""}.esqui-open-kilometers:before{content:""}.esqui-tracks-available:before{content:""}.esqui-ski-lifts:before{content:""}*{margin:0;padding:0}article,aside,audio,canvas,figcaption,figure,figure img,footer,header,hgroup,main,nav,section,video{display:block}a img,fieldset{border:0}body{font-family:Poppins,Trebuchet MS,Helvetica,sans-serif;font-size:.875rem;line-height:1.125rem}img{-moz-user-select:none;-webkit-user-select:none;user-select:none}.accessible{display:none}button,label{cursor:pointer}button,input,legend,textarea{font-family:Poppins,Trebuchet MS,Helvetica,sans-serif;outline:none}input,textarea{-webkit-appearance:none}legend{display:block}a,a:active,a:link,a:visited{fill:var(--I_500);color:var(--C_500);text-decoration:none}ol,ul{list-style-type:none}input[type=checkbox],input[type=checkbox][checked],input[type=radio],input[type=radio][checked]{background-color:transparent;border:0}.table{border-collapse:collapse;border-spacing:0;width:100%}.table thead{background-color:var(--S_50);border:1px solid var(--S_50);text-align:left}.table td,.table th{font-weight:400;padding:15px 30px}.table td~td,.table td~th,.table th~td,.table th~th{border-left:1px solid var(--S_50)}.table td{border-bottom:1px solid var(--S_50)}.footer_links:after,.footer_links:before{content ...
#     </style>
#     <link as="style" href="https://cdn.eltiempo.es/dist/app.bb416ddcfba62c6373f48f29759a0100.css" rel="stylesheet preload"/>
#     <link as="style" href="https://cdn.eltiempo.es/dist/main.abaeffd4b91af3ea2afe355c0675d30c.css" rel="stylesheet preload"/>
#     <link as="style" href="https://cdn.eltiempo.es/dist/grid.b2c524b7e0f4eeecf6d64ac86a69930e.css" rel="stylesheet preload"/>
#     <link as="style" href="https://cdn.eltiempo.es/dist/header.61be0fd49abdf33f2f02aa9775581b7d.css" rel="stylesheet preload"/>
#     <link href="https://cdn.eltiempo.es/images/favicon/v2/eltiempo/favicon48x48.png" rel="apple-touch-icon-precomposed" sizes="48x48"/>
#     <link href="https://cdn.eltiempo.es/images/favicon/v2/eltiempo/favicon32x32.png" rel="apple-touch-icon-precomposed" sizes="32x32"/>
#     <link href="https://cdn.eltiempo.es/images/favicon/v2/eltiempo/favicon16x16.png" rel="shortcut icon"/>
#     <link href="https://cdn.eltiempo.es" rel="preconnect"/>
#     <link href="https://sdk.privacy-center.org" rel="dns-prefetch">
#      <link href="https://cdn.eltiempo.es" rel="dns-prefetch"/>
#      <link href="https://cp.eltiempo.es" rel="preconnect">
#       <script type="text/javascript">
#        if (!window.didomiConfig) {
#         window.didomiConfig = {};
#     }
#     if (!window.didomiConfig.notice) {
#         window.didomiConfig.notice = {};
#     }
#     window.didomiConfig.notice.enable = false;
#       </script>
#       <script data-description="Didomi SDK" type="text/javascript">
#        window.gdprAppliesGlobally = true; (function () { function n(e) { if (!window.frames[e]) { if
#     (document.body && document.body.firstChild) { var t = document.body; var r =
#         document.createElement("iframe"); r.style.display = "none"; r.name = e; r.title = e;
#         t.insertBefore(r, t.firstChild); } else { setTimeout(function () { n(e); }, 5); } } } function e(r,
#         a, o, s, c) { function e(e, t, r, n) { if (typeof r !== "function") { return; } if (!window[a]) {
#         window[a] = []; } var i = false; if (c) { i = c(e, n, r); } if (!i) { window[a].push({ command: e,
#         version: t, callback: r, parameter: n }); } } e.stub = true; e.stubVersion = 2; function t(n) { if
#     (!window[r] || window[r].stub !== true) { return; } if (!n.data) { return; } var i = typeof n.data
#         === "string"; var e; try { e = i ? JSON.parse(n.data) : n.data; } catch (t) { return; } if (e[o]) {
#         var a = e[o]; window[r]( a.command, a.version, function (e, t) { var r = {}; r[s] = { returnValue:
#                 e, success: t, callId: a.callId }; n.source.postMessage(i ? JSON.stringify(r) : r, "*"); },
#             a.parameter ); } } if (typeof window[r] !== "function") { window[r] = e; if
#     (window.addEventListener) { window.addEventListener("message", t, false); } else {
#         window.attachEvent("onmessage", t); } } } e("__uspapi", "__uspapiBuffer", "__uspapiCall",
#         "__uspapiReturn"); n("__uspapiLocator"); e("__tcfapi", "__tcfapiBuffer", "__tcfapiCall",
#         "__tcfapiReturn"); n("__tcfapiLocator"); (function (e) { var t = document.createElement("link");
#         t.rel = "preconnect"; t.as = "script"; var r = document.createElement("link"); r.rel =
#             "dns-prefetch"; r.as = "script"; var n = document.createElement("link"); n.rel = "preload"; n.as =
#             "script"; var i = document.createElement("script"); i.id = "spcloader"; i.type = "text/javascript";
#         i["async"] = true; i.charset = "utf-8"; var a = "https://sdk.privacy-center.org/" + e +
#             "/loader.js?target=" + document.location.hostname; if (window.didomiConfig &&
#             window.didomiConfig.user) { var o = window.didomiConfig.user; var s = o.country; var c = o.region;
#             if (s) { a = a + "&country=" + s; if (c) { a = a + "&region=" + c; } } } t.href =
#             "https://sdk.privacy-center.org/"; r.href = "https://sdk.privacy-center.org/"; n.href = a; i.src =
#             a; var d = document.getElementsByTagName("script")[0]; d.parentNode.insertBefore(t, d);
#         d.parentNode.insertBefore(r, d); d.parentNode.insertBefore(n, d); d.parentNode.insertBefore(i, d);
#     })("c9724c50-1caa-40a9-9c18-ef7c27b8e01b"); })();
#       </script>
#       <script charset="UTF-8" type="text/javascript">
#        !function() {
#         var cpBaseUrl = 'https://cp.eltiempo.es';
#         var cpController = cpBaseUrl + '/now.js';
#         var cpPropertyId = '4fb43238';
#
#         !function(C,o,n,t,P,a,s){C['CPObject']=n;C[n]||(C[n]=function(){
#             (C[n].q=C[n].q||[]).push(arguments)});C[n].l=+new Date;a=o.createElement(t);
#             s=o.getElementsByTagName(t)[0];a.src=P;s.parentNode.insertBefore(a,s)}
#         (window,document,'cp','script',cpController);
#
#         cp('create', cpPropertyId, {
#             baseUrl: cpBaseUrl
#         });
#
#         cp('render', {
#             onFullConsent: function() {
#                 document.cookie = "consent_state=0; SameSite=strict; Secure; path=/";
#             }
#         });
#
#         cp('authenticate', function (error, user) {
#             if (error) {
#                 return;
#             }
#
#             if (user.isLoggedIn() && user.hasValidSubscription()) {
#                 document.cookie = "consent_state=1; SameSite=strict; Secure; path=/";
#             } else {
#                 document.cookie = "consent_state=0; SameSite=strict; Secure; path=/";
#             }
#         });
#     }()
#       </script>
#       <script>
#        function loadAsyncScript(src, id, type = "text/javascript") {
#         if (!document.getElementById(id)) {
#             const e = document.createElement("script");
#             e.async = 1;
#             e.src = src;
#             e.id = id;
#             e.type = type;
#             const f = document.getElementsByTagName("script")[0];
#             f.parentNode.insertBefore(e, f);
#         }
#     }
#       </script>
#       <script>
#        /* '/js/cmp_common.min.js' */
# window.didomiOnReady=window.didomiOnReady||[],window.didomiOnReady.push((function(e){function o(e,o,t){var n=new Date;n.setTime(n.getTime()+24*t*60*60*1e3);var r="expires="+n.toUTCString();document.cookie=e+"="+o+";"+r+";path=/"}e.isConsentRequired()?Didomi.getUserConsentStatusForPurpose("cookies")?o("et_consent","true",360):o("et_consent","false",360):o("et_consent","true",360),e.on("consent.changed",(function(){Didomi.getUserConsentStatusForPurpose("cookies")?o("et_consent","true",360):o("et_consent","false",360)}))})),window.didomiOnReady.push((function(e){e.on("consent.changed",(function(){if(Didomi.getUserConsentStatusForPurpose("measure_ad_performance")&&Didomi.getUserConsentStatusForPurpose("measure_content_performance")&&Didomi.getUserConsentStatusForPurpose("market_research")&&"undefined"!=typeof dataLayer){["cookies","select_basic_ads","create_ads_profile","select_personalized_ads","measure_ad_performance","measure_content_performance","market_research","improve_products","create_content_profile","select_personalized_content"].forEach((function(e){var o=!0===Didomi.getUserConsentStatusForPurpose(e)?"accepted":"rejected";dataLayer.push({event:"didomi-tracking-event",didomiAction:"Purpose "+e+" "+o})}));["google",32,10,577,91,45,52].forEach((function(e){var o="Unknown",t=!0===Didomi.getUserConsentStatusForVendor(e)?"accepted":"rejected";switch(e){case"google":o="Google";break;case 77:o="Comscore";break;case 32:o="App Nexus";break;case 10:o="Index Exchange";break;case 577:o="Neustar / P&G";break;case 91:o="Criteo";break;case 45:o="Smart Ad Server";break;case 52:o="Rubicon Project"}dataLayer.push({event:"didomi-tracking-event",didomiAction:"Vendor "+o+" "+t})}))}}))}));
#       </script>
#       <script>
#        dataLayer = [{
# 		'environment':'pro',
# 		'pageType':'monetizable',
# 		'contentType':'nonSponsored',
# 		'productView':'forecast',
# 		'profileType':'city',
# 		'province':'a-coruna',
# 		'productCity':'a-coruna',
# 		'productDetail':'days',
# 		'niv1':'forecast',
# 		'niv2':'spain',
# 		'niv3':'galicia',
# 		'niv4':'a-coruna',
# 		'niv5':'city',
# 		'locationType':'city',
# 		'currentTemperature':'20ºC',
# 		'weatherForecast':'Mostly clear',
# 		'precipitationProbability':'10',
# 		'windSpeed':'9 km/h',
# 		'ab_testing_variant':'default',
# 	}];
#       </script>
#       <!-- Google Tag Manager -->
#       <script type="text/javascript">
#        (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-K9DJJ6X');
#       </script>
#       <!-- End Google Tag Manager -->
#       <script>
#        window.googletag = window.googletag || {};
#     googletag.cmd = googletag.cmd || [];
#       </script>
#       <script>
#        function loadAsyncScript(src, id, type = "text/javascript") {
#         if (!document.getElementById(id)) {
#             const e = document.createElement("script");
#             e.async = 1;
#             e.src = src;
#             e.id = id;
#             e.type = type;
#             const f = document.getElementsByTagName("script")[0];
#             f.parentNode.insertBefore(e, f);
#         }
#     }
#
#     function loadGoogleAds() {
#         loadAsyncScript(
#             "https://securepubads.g.doubleclick.net/tag/js/gpt.js",
#             "gads_loader_script"
#         );
#     }
#
#     __tcfapi("addEventListener", 2, function (tcData, success) {
#
#         if (!tcData || !success) {
#             return;
#         }
#
#         if (tcData.eventStatus !== "useractioncomplete" && tcData.eventStatus !== "tcloaded") {
#             return;
#         }
#
#         if (tcData.gdprApplies === undefined || !tcData.gdprApplies) {
#
#             loadGoogleAds();
#
#         } else {
#
#             if (!tcData.vendor || !tcData.vendor.consents) {
#                 return;
#             }
#
#             if (tcData.vendor.consents[755]) {
#                 loadGoogleAds();
#             }
#
#         }
#
#         if (tcData.listenerId) {
#             __tcfapi("removeEventListener", 2, function () {}, tcData.listenerId);
#         }
#
#     });
#       </script>
#       <script async="" src="https://cdns3.eltiempo.es/assets/js/prebid/8.36.0/dist/prebid.js" type="didomi/javascript">
#       </script>
#       <script async="" src="https://cdn.eltiempo.es/dist/header.a93ef1be9ef4b06312cfb2b16f262764.js" type="didomi/javascript">
#       </script>
#       <script async="" src="//optiyield.opti-digital.com/pfc/?pubid=21818248268">
#       </script>
#       <script async="" src="https://boot.pbstck.com/v1/tag/b7bb964b-8f8b-4710-9a06-9775d8225e26">
#       </script>
#       <script>
#        var JSCDNURL = "https://cdn.eltiempo.es";
#         var COOKIE_DOMAIN_VISITOR = ".eltiempo.es";
#         var BODY_ID = "city";
#         var ADD_UNIT_BASE = "/21818248268/web-eltiempo.es/";
#       </script>
#       <script>
#        const pageKeyValues = {"page_language":"es","body_id":"city","ab_testing_variant":"default","foreca_id":"103119841","urlized":"a-coruna","poi_name":"A Coru\u00f1a","etcity_type":"city","continent":"EUR","country":"es","community":"galicia","weather_icon":"100","wind_speed":9,"region":"a-coruna","city_tab":"city_days","temp_c":19,"max_temp":"","clouds_level":"mostly-clear","precip_amount":"none","precip_type":"none","pressure":"1011.59996","humidity":"63","uv_radiation":5,"nx_monday_weather_icon":"210","nx_monday_temp_average":65,"nx_tuesday_weather_icon":"200","nx_tuesday_temp_average":64,"nx_wednesday_weather_icon":"410","nx_wednesday_temp_average":60,"nx_thursday_weather_icon":"220","nx_thursday_temp_average":65,"nx_friday_weather_icon":"200","nx_friday_temp_average":59,"nx_saturday_weather_icon":"200","nx_saturday_temp_average":59,"nx_sunday_weather_icon":"210","nx_sunday_temp_average":62,"aqi":"good","no2":"good","so2":"good","o3":"good","pm25":"good","pm10":"good","co":"good","pollen_level":"nothing","flu_info":"no"};
#                 const ADPOSITIONS = [[{"adDiv":"div-box-one-ct","dfpSizes":{"mobile":[[300,250],[300,300],[320,100],[300,400]],"desktop":[[970,250],[980,250],[980,90],[970,90],[728,90],[990,250]],"tablet":[[728,90]]},"prebidSizes":{"mobile":[[300,250]],"desktop":[[970,250],[980,250],[980,90],[970,90],[728,90],[990,250]],"tablet":[[728,90]]},"criteoPublisherSubId":"Posici\u00f3n_1","adPosition":"1","adUnit":"/21818248268/web-eltiempo.es/forecast/city/days/1","hideIn":[]}],[{"adDiv":"div-box-two","dfpSizes":{"mobile":[[320,50],[320,100],[300,250],[300,50],[300,100],[300,600]],"desktop":[[300,600],[300,250],[160,600]],"tablet":[[300,600],[300,250],[980,90],[970,90],[728,90],[336,280]]},"prebidSizes":{"mobile":[[320,50],[320,100],[300,250],[300,50],[300,100]],"desktop":[[300,600],[300,250],[160,600]],"tablet":[[300,600],[160,600],[300,250]]},"criteoPublisherSubId":"Posici\u00f3n_2","adPosition":"2","adUnit":"/21818248268/web-eltiempo.es/forecast/city/days/2","hideIn":[]}],[{"adDiv":"div-box-three","dfpSizes":{"mobile":[[320,50],[320,100],[300,250],[300,50],[300,100],[300,600]],"desktop":[[970,250],[980,250],[980,90],[970,90],[728,90],[990,250]],"tablet":[[728,90],[300,250],[980,90],[970,90],[336,280],[300,600]]},"prebidSizes":{"mobile":[[320,50],[320,100],[300,250],[300,50],[300,100]],"desktop":[[970,250],[980,250],[980,90],[970,90],[728,90],[990,250]],"tablet":[[728,90],[300,250],[300,300]]},"criteoPublisherSubId":"Posici\u00f3n_3","adPosition":"3","adUnit":"/21818248268/web-eltiempo.es/forecast/city/days/3","hideIn":[]}],[{"adDiv":"div-box-in-feed","dfpSizes":{"mobile":[[320,50],[320,100],[300,250],[336,280]],"desktop":[[300,600],[300,250],[300,400]],"tablet":[[320,50],[320,100],[300,250],[336,280]]},"prebidSizes":{"mobile":[[320,50],[320,100],[300,250],[336,280]],"desktop":[[300,600],[300,250],[300,400]],"tablet":[[320,50],[320,100],[300,250],[336,280]]},"adPosition":"infeed","adUnit":"/21818248268/web-eltiempo.es/forecast/city/days/infeed","hideIn":[]}],[{"adDiv":"div-box-in-table","dfpSizes":{"mobile":[[320,50],[320,100]],"desktop":[[320,50],[320,100]],"tablet":[[320,50],[320,100]]},"prebidSizes":{"mobile":[[320,50],[320,100]],"desktop":[[320,50],[320,100]],"tablet":[[320,50],[320,100]]},"adPosition":"intable","adUnit":"/21818248268/web-eltiempo.es/forecast/city/days/intable","hideIn":[]}],[{"adDiv":"div-box-sticky","dfpSizes":{"mobile":[[320,50],[320,51],[320,100],[1,1]],"desktop":[[728,90],[728,91]],"tablet":[[728,90],[728,91]]},"prebidSizes":{"mobile":[[320,50],[320,51],[320,100],[1,1]],"desktop":[[728,90],[728,91]],"tablet":[[728,90],[728,91]]},"adPosition":"sticky","adUnit":"/21818248268/web-eltiempo.es/forecast/city/days/sticky","hideIn":[]}],[{"adDiv":"div-gpt-ad-tk","dfpSizes":{"mobile":[[1,1]],"desktop":[[1,1],[1680,1050]],"tablet":[[1,1]]},"prebidSizes":{"mobile":[[1,1]],"desktop":[[1,1],[1680,1050]],"tablet":[[1,1]]},"adPosition":"skin","adUnit":"/21818248268/web-eltiempo.es/forecast/city/days/skin","hideIn":[]}]];
#                 const OUTOFPAGE_ADPOSITIONS = [[{"adDiv":"div-gpt-ad-ist","adPosition":"interstitial","adUnit":"/21818248268/web-eltiempo.es/forecast/city/days/interstitial","hideIn":[]}]];
#                 const SITENAMEADS = "eltiempo";
#                 const SITEURLADS = "Eltiempo.es";
#                 const FAILSAFE_TIMEOUT = 1800;
#                 const TIMEOUT_PREBID = 1800;
#                 const BIDDER_TIMEOUT = 1800;
#       </script>
#       <script type="text/javascript">
#        window.didomiOnReady = window.didomiOnReady || [];
#
#     function getCookie(name) {
#         var value = "; " + document.cookie;
#         var parts = value.split("; " + name + "=");
#         if (parts.length === 2) return parts.pop().split(";").shift();
#     }
#
#     var enforced_page_URL = '';
#
#     googletag.cmd.push(function () {
#         if (enforced_page_URL !== '') {
#             googletag.pubads().set('page_url', enforced_page_URL);
#         }
#
#         window.didomiOnReady.push(function (Didomi) {
#
#             if (Didomi.getUserConsentStatusForPurpose('create_ads_profile') !== undefined && Didomi.getUserConsentStatusForPurpose('create_ads_profile') &&
#                 Didomi.getUserConsentStatusForPurpose('create_content_profile') !== undefined && Didomi.getUserConsentStatusForPurpose('create_content_profile')) {
#
#                 var last_gps_foreca_id = '';
#                 var last_gps_urlized = '    ';
#                 var last_gps_region_urlized = '';
#                 var last_gps_country = '';
#                 var last_gps_location_info = getCookie('last_gps_location_info');
#                 if (last_gps_location_info !== undefined) {
#                     values = last_gps_location_info.split('|');
#                     last_gps_foreca_id = values[0];
#                     last_gps_urlized = values[1];
#                     last_gps_region_urlized = values[2];
#                     last_gps_country = values[3];
#                     googletag.pubads().setTargeting('last_gps_foreca_id', last_gps_foreca_id).setTargeting('last_gps_urlized', last_gps_urlized).setTargeting('last_gps_region_urlized', last_gps_region_urlized).setTargeting('last_gps_country', last_gps_country);
#                 }
#
#             } else {
#                 if (navigator.cookieEnabled === false) {
#                     googletag.pubads().setTargeting('user_has_cookies', '0');
#                 }
#             }
#         })
#
#                 googletag.pubads()
#         .setTargeting('page_language', 'es').setTargeting('body_id', 'city').setTargeting('ab_testing_variant', 'default').setTargeting('foreca_id', '103119841').setTargeting('urlized', 'a-coruna').setTargeting('poi_name', 'A Coruña').setTargeting('etcity_type', 'city').setTargeting('continent', 'EUR').setTargeting('country', 'es').setTargeting('community', 'galicia').setTargeting('weather_icon', '100').setTargeting('wind_speed', '9').setTargeting('region', 'a-coruna').setTargeting('city_tab', 'city_days').setTargeting('temp_c', '19').setTargeting('max_temp', '').setTargeting('clouds_level', 'mostly-clear').setTargeting('precip_amount', 'none').setTargeting('precip_type', 'none').setTargeting('pressure', '1011.59996').setTargeting('humidity', '63').setTargeting('uv_radiation', '5').setTargeting('nx_monday_weather_icon', '210').setTargeting('nx_monday_temp_average', '65').setTargeting('nx_tuesday_weather_icon', '200').setTargeting('nx_tuesday_temp_average', '64').setTargeting('nx_wednesday_weather_icon', '410').setTargeting('nx_wednesday_temp_average', '60').setTargeting('nx_thursday_weather_icon', '220').setTargeting('nx_thursday_temp_average', '65').setTargeting('nx_friday_weather_icon', '200').setTargeting('nx_friday_temp_average', '59').setTargeting('nx_saturday_weather_icon', '200').setTargeting('nx_saturday_temp_average', '59').setTargeting('nx_sunday_weather_icon', '210').setTargeting('nx_sunday_temp_average', '62').setTargeting('aqi', 'good').setTargeting('no2', 'good').setTargeting('so2', 'good').setTargeting('o3', 'good').setTargeting('pm25', 'good').setTargeting('pm10', 'good').setTargeting('co', 'good').setTargeting('pollen_level', 'nothing').setTargeting('flu_info', 'no') ;
#
#
#     })
#       </script>
#       <script async="" src="https://cdn.eltiempo.es/dist/ads/index.82b982dacdc13b23e57e18d37c214294.js" type="didomi/javascript">
#       </script>
#       <link href="https://www.eltiempo.es/a-coruna.html" hreflang="es-es" rel="alternate">
#        <link href="https://ca.eltiempo.es/a-coruna.html" hreflang="ca" rel="alternate">
#         <link href="https://eus.eltiempo.es/a-coruna.html" hreflang="eu" rel="alternate">
#          <link href="https://gal.eltiempo.es/a-coruna.html" hreflang="gl" rel="alternate">
#           <link href="https://de.eltiempo.es/a-coruna.html" hreflang="de" rel="alternate">
#            <link href="https://en.eltiempo.es/a-coruna.html" hreflang="en" rel="alternate">
#             <link href="https://fr.eltiempo.es/a-coruna.html" hreflang="fr" rel="alternate">
#              <link href="https://it.eltiempo.es/a-coruna.html" hreflang="it" rel="alternate">
#               <link href="https://www.clima.com/espana/galicia/a-coruna" hreflang="es" rel="alternate"/>
#               <link href="https://www.climadobrasil.com.br/espanha/galicia/a-coruna" hreflang="pt-br" rel="alternate"/>
#               <link href="https://www.otempo.pt/a-coruna.html" hreflang="pt-pt" rel="alternate"/>
#               <script type="text/javascript">
#                var current_location_info = {};
#                                                     // prepare all the data for the PSS alert system
#                 current_location_info['foreca_id'] = "103119841";
#                 current_location_info['urlized'] = "a-coruna";
#                 current_location_info['pelmorex_id'] = "ESXX0016";
#                 current_location_info['name'] = "A Coruña";
#                 current_location_info['region_name'] = "A Coruña";
#                 current_location_info['country_name'] = "";
#                 current_location_info['pss'] = "";
#                                     current_location_info['url'] = "/a-coruna.html";
#                                     current_location_info['weather'] = "";
#                 current_location_info['timestamp'] = "";
#                 current_location_info['city_page_pelmorex_id'] = "ESXX0016";
#                 current_location_info['is_gps'] = false;
#               </script>
#               <style>
#                #appsflyer-placeholder {
#         position:fixed;
#         bottom: 0;
#         width:100%;
#         z-index: 2;
#     }
#     #appsflyer-placeholder button {
#         min-width: auto;
#     }
#               </style>
#               <script data-purposes="cookies" type="didomi/javascript">
#                !function(t,e,n,s,a,c,i,o,p){t.AppsFlyerSdkObject=a,t.AF=t.AF||function(){(t.AF.q=t.AF.q||[]).push([Date.now()].concat(Array.prototype.slice.call(arguments)))},t.AF.id=t.AF.id||i,t.AF.plugins={},o=e.createElement(n),p=e.getElementsByTagName(n)[0],o.async=1,o.src="https://websdk.appsflyer.com?"+(c.length>0?"st="+c.split(",").sort().join(",")+"&":"")+(i.length>0?"af_id="+i:""),p.parentNode.insertBefore(o,p)}(window,document,"script",0,"AF","banners",{banners: {key: "cc77f8a1-947b-4a5d-8c91-ee735d3dcbed"}})
#     AF('banners', 'showBanner', { bannerContainerQuery: '#appsflyer-placeholder' });
#               </script>
#              </link>
#             </link>
#            </link>
#           </link>
#          </link>
#         </link>
#        </link>
#       </link>
#      </link>
#     </link>
#    </meta>
#   </meta>
#  </head>
#  <body class="bg bg_general page-city" data-user-status="">
#   <script data-vendor="iab:77" type="didomi/javascript">
#    var _comscore = _comscore || [];
#     let cs_ucfr_value = "1";
#     _comscore.push({ c1: "2", c2: "6035832", cs_ucfr: cs_ucfr_value});
#     var s = document.createElement("script"),
#         el = document.getElementsByTagName("script")[0];
#     s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") +
#         ".scorecardresearch.com/cs/6035832/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   </script>
#   <div id="div-gpt-ad-tk">
#   </div>
#   <div id="div-gpt-ad-pts">
#   </div>
#   <div id="div-gpt-ad-ist">
#   </div>
#   <div id="sticky-box-container">
#    <div class="sticky-banner gtm-content-sticky" data-key-values='{"page_language":"es","body_id":"city","ab_testing_variant":"default","foreca_id":"103119841","urlized":"a-coruna","poi_name":"A Coru\u00f1a","etcity_type":"city","continent":"EUR","country":"es","community":"galicia","weather_icon":"100","wind_speed":9,"region":"a-coruna","city_tab":"city_days","temp_c":19,"max_temp":"","clouds_level":"mostly-clear","precip_amount":"none","precip_type":"none","pressure":"1011.59996","humidity":"63","uv_radiation":5,"nx_monday_weather_icon":"210","nx_monday_temp_average":65,"nx_tuesday_weather_icon":"200","nx_tuesday_temp_average":64,"nx_wednesday_weather_icon":"410","nx_wednesday_temp_average":60,"nx_thursday_weather_icon":"220","nx_thursday_temp_average":65,"nx_friday_weather_icon":"200","nx_friday_temp_average":59,"nx_saturday_weather_icon":"200","nx_saturday_temp_average":59,"nx_sunday_weather_icon":"210","nx_sunday_temp_average":62,"aqi":"good","no2":"good","so2":"good","o3":"good","pm25":"good","pm10":"good","co":"good","pollen_level":"nothing","flu_info":"no"}' id="sticky-banner" style="bottom: -130px">
#     <div class="sticky-container">
#      <a class="close-button gtm-button-sticky-closeIcon" href="#" id="sticky-close">
#       <i class="icon icon-xs icon-close">
#       </i>
#      </a>
#      <div id="div-box-sticky">
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="hot-topics-container">
#    <div class="container-row hot-topics">
#     <div class="row-content mb-0 gx-0 pre-list">
#      <div class="desk col-lg-3">
#       <div class="hot-title-content">
#        <span class="hot-title text-roboto-condensed-bold">
#         Meteorología &amp; Sostenibilidad
#        </span>
#        <span class="hot-title-division">
#        </span>
#        <span class="hot-title-subtitle text-roboto-condensed">
#         Es noticia:
#        </span>
#       </div>
#      </div>
#      <div class="col-lg-9">
#       <div class="container-list text-roboto-condensed">
#        <ul class="list">
#         <li>
#          <a class="gtm-header-hottopics-1" data-fin-de-semana-highlighted="" href="https://www.eltiempo.es/noticias/mario-picazo-responde-hasta-cuando-seguira-lloviendo-en-espana">
#           Fin de semana
#          </a>
#         </li>
#         <li>
#          <a class="gtm-header-hottopics-2" data-cambio-de-armario-highlighted="" href="https://www.eltiempo.es/noticias/cambio-de-armario-temperaturas">
#           Cambio de armario
#          </a>
#         </li>
#         <li>
#          <a class="gtm-header-hottopics-3" data-hasta-cuando-dana-highlighted="" href="https://www.eltiempo.es/noticias/las-tormentas-seguiran-en-estas-zonas-la-proxima-semana-y-habra-que-abrigarse-por-la-noche-que-tiempo-hara-la-proxima-semana">
#           Hasta cuándo DANA
#          </a>
#         </li>
#         <li>
#          <a class="gtm-header-hottopics-4" data-tifon-china-highlighted="" href="https://www.eltiempo.es/noticias/el-tifon-yagi-obliga-a-suspender-clases-y-trabajos-en-el-sur-de-china">
#           Tifón China
#          </a>
#         </li>
#         <li>
#          <a class="gtm-header-hottopics-5" data-verano-mas-calido-highlighted="" href="https://www.eltiempo.es/noticias/verano-2024-calido">
#           Verano más cálido
#          </a>
#         </li>
#         <li>
#          <a class="gtm-header-hottopics-6" data-eclipse-luna-septiembre-highlighted="" href="https://www.eltiempo.es/noticias/todo-sobre-el-eclipse-lunar-parcial-de-septiembre-de-2024">
#           Eclipse Luna Septiembre
#          </a>
#         </li>
#         <li>
#          <a class="gtm-header-hottopics-7" data-otono-cuando-empieza-highlighted="" href="https://www.eltiempo.es/noticias/cuando-empieza-el-otono-2024">
#           Otoño cuándo empieza
#          </a>
#         </li>
#        </ul>
#        <div class="container-icon">
#         <i class="icon hidden icon-chevron-right gtm-header-hottopics-next">
#         </i>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <header data-lang="es-es" id="header">
#    <div class="navbar-container">
#     <nav class="container-row gtm-header-bar" id="navbar">
#      <div class="navbar row-content">
#       <div class="col-2 col-md-3">
#        <div class="navbar-logo" id="navbarLogo">
#         <a class="gtm-header-logo" href="/">
#          <img alt="El tiempo: previsión meteorológica" class="hidden-desktop" height="32" src="https://cdn.eltiempo.es/images/content/eltiempo-mobile.svg" width="32"/>
#          <img alt="El tiempo: previsión meteorológica" class="hidden-mobile" height="48" src="https://cdn.eltiempo.es/images/content/logo2x.svg" width="142"/>
#         </a>
#        </div>
#       </div>
#       <div class="col-8 col-md-7" id="search">
#        <search :form-regions='{"world":"\/el-mundo","country":"\/espana","countryText":"Regiones de Espa\u00f1a"}' data-poi="ESXX0016" site-api-url="https://api.eltiempo.es/api/v2/" site-code="es" site-name="eltiempo" site-recaptcha-key="6LeoDlkUAAAAAP_WYuEtCQDYHhVavENz9VV6uQAk" site-tmp="80e22e64348dbdb1fb5cc0f24edd95dabca7737ab486ed4843ed39eec6e499a6" token-csrf="WuceAtyuUgDKEvH1XaoRvK04SncCqc9E3A52C3a5" user-hash="89725a7bf1f961ef2c91abc9f274fa80">
#        </search>
#       </div>
#       <div class="col-2 hamburger-container">
#        <button class="hamburger gtm-header-menu-open" id="headerHamburgerMenu">
#        </button>
#       </div>
#      </div>
#      <div class="dropdown elt-anim-fade" id="dropdown">
#       <div class="container-row dropdown-content" id="dropdown-content">
#        <section class="navbar__collapse container-row" id="dropdown-collapse">
#         <div class="row-content mb-0">
#          <div class="col-12 col-lg-6">
#           <p class="submenu-title">
#            <span class="arrow-icon">
#             Previsión
#             <i class="icon icon-chevron-down-blue">
#             </i>
#            </span>
#           </p>
#           <div class="row-content p-0 mb-0 collapse">
#            <div class="col-12 des-d-flex">
#             <div class="col-12 col-lg-6">
#              <p class="submenu-subtitle">
#               POR TIPO DE MAPA
#              </p>
#              <ul class="submenu-list container-row des-d-flex g-0">
#               <li class="nav-item col-6 col-lg-6">
#                <a class="nav-link gtm-menu-link" href="/lluvia">
#                 Lluvia y nieve
#                </a>
#               </li>
#               <li class="nav-item col-6 col-lg-6">
#                <a class="nav-link gtm-menu-link" href="/temperatura">
#                 Temperatura
#                </a>
#               </li>
#               <li class="nav-item col-6 col-lg-6">
#                <a class="nav-link gtm-menu-link" href="/presion">
#                 Presión
#                </a>
#               </li>
#               <li class="nav-item col-6 col-lg-6">
#                <a class="nav-link gtm-menu-link" href="/radar">
#                 Radar
#                </a>
#               </li>
#               <li class="nav-item col-6 col-lg-6">
#                <a class="nav-link gtm-menu-link" href="/nubes">
#                 Nubes
#                </a>
#               </li>
#               <li class="nav-item col-6 col-lg-6">
#                <a class="nav-link gtm-menu-link" href="/viento">
#                 Viento
#                </a>
#               </li>
#               <li class="nav-item col-6 col-lg-6">
#                <a class="nav-link gtm-menu-link" href="/europa/satelite">
#                 Satélite
#                </a>
#               </li>
#              </ul>
#             </div>
#             <div class="col-12 col-lg-6">
#              <p class="submenu-subtitle">
#               POR ZONAS GEOGRÁFICAS
#              </p>
#              <ul class="submenu-list container-row des-d-flex g-0">
#               <li class="nav-item col-6 col-lg-12">
#                <a class="nav-link gtm-menu-link" href="/playas">
#                 Playas
#                </a>
#               </li>
#               <li class="nav-item col-6 col-lg-12">
#                <a class="nav-link gtm-menu-link" href="/costas">
#                 Costas
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class="col-12">
#             <p class="submenu-subtitle">
#              POR REGIONES
#             </p>
#             <ul class="submenu-list container-row des-d-flex g-0">
#              <li class="col-6 col-lg-3">
#               <a class="nav-link gtm-menu-link" href="/el-mundo">
#                Mundo
#               </a>
#              </li>
#              <li class="col-6 col-lg-3">
#               <a class="nav-link gtm-menu-link" href="/">
#                España
#               </a>
#              </li>
#              <li class="col-6 col-lg-3 col-lg-6">
#               <a class="nav-link gtm-menu-link" href="/espana">
#                CCAA, provincias e islas
#               </a>
#              </li>
#             </ul>
#            </div>
#            <div class="col-12">
#             <p class="submenu-subtitle">
#              PRINCIPALES CIUDADES
#             </p>
#             <div class="submenu-list container-row des-d-flex g-0">
#              <ul class="cities-list">
#               <li>
#                <a class="nav-link gtm-menu-link" href="/madrid.html" title="El tiempo en Madrid">
#                 Madrid
#                </a>
#               </li>
#               <li>
#                <a class="nav-link gtm-menu-link" href="/malaga.html" title="El tiempo en Málaga">
#                 Málaga
#                </a>
#               </li>
#               <li>
#                <a class="nav-link gtm-menu-link" href="/barcelona.html" title="El tiempo en Barcelona">
#                 Barcelona
#                </a>
#               </li>
#               <li>
#                <a class="nav-link gtm-menu-link" href="/santander.html" title="El tiempo en Santander">
#                 Santander
#                </a>
#               </li>
#              </ul>
#              <ul class="cities-list">
#               <li>
#                <a class="nav-link gtm-menu-link" href="/sevilla.html" title="El tiempo en Sevilla">
#                 Sevilla
#                </a>
#               </li>
#               <li>
#                <a class="nav-link gtm-menu-link" href="/bilbao.html" title="El tiempo en Bilbao">
#                 Bilbao
#                </a>
#               </li>
#               <li>
#                <a class="nav-link gtm-menu-link" href="/granada.html" title="El tiempo en Granada">
#                 Granada
#                </a>
#               </li>
#               <li>
#                <a class="nav-link gtm-menu-link" href="/pamplona.html" title="El tiempo en Pamplona">
#                 Pamplona
#                </a>
#               </li>
#              </ul>
#              <ul class="cities-list">
#               <li>
#                <a class="nav-link gtm-menu-link" href="/valencia.html" title="El tiempo en Valencia">
#                 Valencia
#                </a>
#               </li>
#               <li>
#                <a class="nav-link gtm-menu-link" href="/cordoba.html" title="El tiempo en Córdoba">
#                 Córdoba
#                </a>
#               </li>
#               <li>
#                <a class="nav-link gtm-menu-link" href="/zaragoza.html" title="El tiempo en Zaragoza">
#                 Zaragoza
#                </a>
#               </li>
#               <li>
#                <a class="nav-link gtm-menu-link" href="/gijon.html" title="El tiempo en Gijón">
#                 Gijón
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="col-12 col-lg-6">
#           <div class="row-content mb-0">
#            <div class="col-12 col-lg-6">
#             <p class="submenu-title">
#              <span class="arrow-icon">
#               Salud ambiental
#               <i class="icon icon-chevron-down-blue">
#               </i>
#              </span>
#             </p>
#             <ul class="submenu-list des-d-flex collapse">
#              <li class="nav-item col-6 col-lg-12">
#               <a class="nav-link gtm-menu-link" href="/calidad-aire">
#                Calidad del aire
#               </a>
#              </li>
#              <li class="nav-item col-6 col-lg-12">
#               <a class="nav-link gtm-menu-link" href="/polen">
#                Polen
#               </a>
#              </li>
#              <li class="nav-item col-6 col-lg-12">
#               <a class="nav-link gtm-menu-link" href="/gripe">
#                Gripe
#               </a>
#              </li>
#             </ul>
#             <p class="submenu-title">
#              <span class="arrow-icon">
#               Actividades
#               <i class="icon icon-chevron-down-blue">
#               </i>
#              </span>
#             </p>
#             <ul class="submenu-list des-d-flex collapse">
#              <li class="nav-item col-6 col-lg-12">
#               <a class="nav-link gtm-menu-link" href="/deportes-nauticos">
#                Deportes náuticos
#               </a>
#              </li>
#              <li class="nav-item col-6 col-lg-12">
#               <a class="nav-link gtm-menu-link" href="/esqui">
#                Esquí
#               </a>
#              </li>
#             </ul>
#            </div>
#            <div class="col-12 col-lg-6">
#             <p class="submenu-title">
#              <span class="arrow-icon">
#               Noticias
#               <i class="icon icon-chevron-down-blue">
#               </i>
#              </span>
#             </p>
#             <ul class="submenu-list des-d-flex collapse news-list">
#              <li class="nav-item col-6 col-lg-12">
#               <a class="nav-link gtm-menu-link" href="/noticias">
#                Portada
#               </a>
#              </li>
#              <li class="nav-item col-6 col-lg-12">
#               <a class="nav-link gtm-menu-link" href="/noticias/cambio-climatico">
#                Cambio climático
#               </a>
#              </li>
#              <li class="nav-item col-6 col-lg-12">
#               <a class="nav-link gtm-menu-link" href="/noticias/sostenibilidad">
#                Sostenibilidad
#               </a>
#              </li>
#              <li class="nav-item col-6 col-lg-12">
#               <a class="nav-link gtm-menu-link" href="/noticias/prevision">
#                Meteorología
#               </a>
#              </li>
#              <li class="nav-item col-6 col-lg-12">
#               <a class="nav-link gtm-menu-link" href="/noticias/vida-saludable">
#                Vida saludable
#               </a>
#              </li>
#              <li class="nav-item col-6 col-lg-12">
#               <a class="nav-link gtm-menu-link" href="/noticias/escapadas">
#                Escapadas
#               </a>
#              </li>
#              <li class="nav-item col-6 col-lg-12">
#               <a class="nav-link gtm-menu-link" href="/noticias/tiempo-libre">
#                Tiempo libre
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="row-content sub-header">
#          <div class="col-12 col-lg-3 subheader-col">
#           <p class="subheader-title">
#            <span>
#             Servicios
#            </span>
#           </p>
#           <ul>
#            <li class="nav-item col-6">
#             <a class="nav-link" href="https://weathersource.com/">
#              Pelmorex API Weather
#             </a>
#            </li>
#            <li class="nav-item col-6">
#             <a class="nav-link" href="https://www.pelmorexcorp.es/">
#              Pelmorex España
#             </a>
#            </li>
#            <li class="nav-item col-6">
#             <a class="nav-link" href="/widget">
#              Widget ElTiempo.es
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="col-12 col-lg-3 subheader-col">
#           <p class="subheader-title">
#            <span>
#             Otros productos
#            </span>
#           </p>
#           <ul>
#            <li class="nav-item col-6">
#             <a class="nav-link" href="https://descubre-nueva-app.eltiempo.es/">
#              Descarga nuestra app
#             </a>
#            </li>
#            <li class="nav-item col-6">
#             <a class="nav-link" href="/noticias/meteopedia">
#              Meteopedia climática
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="col-12 col-lg-3 subheader-col">
#           <p class="subheader-title">
#            <span>
#             Contáctanos
#            </span>
#           </p>
#           <ul>
#            <li class="nav-item col-6">
#             <a class="nav-link" href="mailto:info@eltiempo.es">
#              Escríbenos
#             </a>
#            </li>
#            <li>
#             <ul class="follow-us">
#              <li>
#               <a href="https://bit.ly/FacebookElTiempo" rel="nofollow" target="_blank">
#                <img alt="Facebook" src="https://cdn.eltiempo.es/dist/images/icons/general/svg/facebook.svg"/>
#               </a>
#              </li>
#              <li>
#               <a href="https://bit.ly/InstagramElTiempo" rel="nofollow" target="_blank">
#                <img alt="Instagram" src="https://cdn.eltiempo.es/dist/images/icons/general/svg/instagram.svg"/>
#               </a>
#              </li>
#              <li>
#               <a href="https://bit.ly/TwitterElTiempo" rel="nofollow" target="_blank">
#                <img alt="Twitter" src="https://cdn.eltiempo.es/dist/images/icons/general/svg/twitter.svg"/>
#               </a>
#              </li>
#              <li>
#               <a href="https://bit.ly/LinkedinElTiempo" rel="nofollow" target="_blank">
#                <img alt="Linkedin" src="https://cdn.eltiempo.es/dist/images/icons/general/svg/linkedin.svg"/>
#               </a>
#              </li>
#              <li>
#               <a href="https://spoti.fi/3GX8l0B" rel="nofollow" target="_blank">
#                <img alt="Spotify" src="https://cdn.eltiempo.es/dist/images/icons/general/svg/spotify.svg"/>
#               </a>
#              </li>
#             </ul>
#            </li>
#           </ul>
#          </div>
#          <div class="col-12 col-lg-3 subheader-col">
#           <p class="subheader-title">
#            <span>
#             Legal
#            </span>
#           </p>
#           <ul>
#            <li class="nav-item col-6">
#             <a class="nav-link" href="/legal/condiciones-generales.html">
#              Aviso legal
#             </a>
#            </li>
#            <li class="nav-item col-6">
#             <a class="nav-link" href="/legal/politica-cookies.html">
#              Política de cookies
#             </a>
#            </li>
#            <li class="nav-item col-6">
# ...
#                 </i>
#                </div>
#                <p class="velocity" data-speed="12" data-speed-include-units="1">
#                 <span class="wind-text-value" data-speed-include-units="1">
#                  12
#                 </span>
#                 <span class="wind-text-unit">
#                  km/h
#                 </span>
#                </p>
#               </td>
#               <td class="wind">
#                <div>
#                 <i class="icon icon-sm icon-direction east">
#                 </i>
#                </div>
#                <p class="velocity" data-speed="12" data-speed-include-units="1">
#                 <span class="wind-text-value" data-speed-include-units="1">
#                  12
#                 </span>
#                 <span class="wind-text-unit">
#                  km/h
#                 </span>
#                </p>
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <i class="icon icon-md icon-dawn">
#                </i>
#               </td>
#               <td>
#                08:03
#               </td>
#               <td>
#                08:04
#               </td>
#               <td>
#                08:05
#               </td>
#               <td>
#                08:06
#               </td>
#               <td>
#                08:07
#               </td>
#               <td>
#                08:08
#               </td>
#               <td>
#                08:10
#               </td>
#               <td>
#                08:11
#               </td>
#               <td>
#                08:12
#               </td>
#               <td>
#                08:13
#               </td>
#               <td>
#                08:14
#               </td>
#               <td>
#                08:15
#               </td>
#               <td>
#                08:16
#               </td>
#               <td>
#                08:17
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <i class="icon icon-md icon-dusk">
#                </i>
#               </td>
#               <td>
#                20:59
#               </td>
#               <td>
#                20:57
#               </td>
#               <td>
#                20:55
#               </td>
#               <td>
#                20:54
#               </td>
#               <td>
#                20:52
#               </td>
#               <td>
#                20:50
#               </td>
#               <td>
#                20:48
#               </td>
#               <td>
#                20:46
#               </td>
#               <td>
#                20:44
#               </td>
#               <td>
#                20:43
#               </td>
#               <td>
#                20:41
#               </td>
#               <td>
#                20:39
#               </td>
#               <td>
#                20:37
#               </td>
#               <td>
#                20:35
#               </td>
#              </tr>
#             </tbody>
#            </table>
#           </div>
#          </div>
#         </section>
#         <div class="modules mods-box mods-box-vertical">
#          <div class="mods-box-body" id="div-box-two">
#          </div>
#         </div>
#        </section>
#        <hr class="hide_for_mobile hide_for_tablet"/>
#        <section class="block_full row-content lazyloadcontent row_box row_number_4" data-content-src="/a-coruna.html~ROW_NUMBER_4~~TEMP_UNIT_c~~WIND_UNIT_kmh~">
#         <div class="col-12 m36 m36--climateaverage -d-flex -j-center -ai-center">
#          <p>
#           <i class="icon icon-md icon-spinner icon-rotate">
#           </i>
#          </p>
#         </div>
#        </section>
#       </main>
#       <aside>
#        <section class="block_full row-content lazyloadcontent row_box row_number_5" data-content-src="/a-coruna.html~ROW_NUMBER_5~~TEMP_UNIT_c~~WIND_UNIT_kmh~">
#         <div class="col-12 m36 m36--advertising -d-flex -j-center -ai-center">
#          <p>
#           <i class="icon icon-md icon-spinner icon-rotate">
#           </i>
#          </p>
#         </div>
#        </section>
#        <section class="block_full row-content lazyloadcontent row_box row_number_6" data-content-src="/a-coruna.html~ROW_NUMBER_6~~TEMP_UNIT_c~~WIND_UNIT_kmh~">
#         <div class="col-12 m36 m36--separator -d-flex -j-center -ai-center">
#          <p>
#           <i class="icon icon-md icon-spinner icon-rotate">
#           </i>
#          </p>
#         </div>
#        </section>
#        <section class="block_thirds row-content lazyloadcontent row_box row_number_7" data-content-src="/a-coruna.html~ROW_NUMBER_7~~TEMP_UNIT_c~~WIND_UNIT_kmh~" data-equalize="">
#         <div class="col-12 m36 m36--onecontent-editorial-onecontent -d-flex -j-center -ai-center">
#          <p>
#           <i class="icon icon-md icon-spinner icon-rotate">
#           </i>
#          </p>
#         </div>
#        </section>
#        <hr class="hide_for_mobile hide_for_tablet"/>
#        <section class="block_thirds_left row-content lazyloadcontent row_box row_number_8" data-content-src="/a-coruna.html~ROW_NUMBER_8~~TEMP_UNIT_c~~WIND_UNIT_kmh~" data-equalize="">
#         <div class="col-12 m36 m36--editorial-brandedcontentpersonalized -d-flex -j-center -ai-center">
#          <p>
#           <i class="icon icon-md icon-spinner icon-rotate">
#           </i>
#          </p>
#         </div>
#        </section>
#        <hr class="hide_for_mobile hide_for_tablet"/>
#        <section class="block_thirds_left row-content lazyloadcontent row_box row_number_9" data-content-src="/a-coruna.html~ROW_NUMBER_9~~TEMP_UNIT_c~~WIND_UNIT_kmh~" data-equalize="">
#         <div class="col-12 m36 m36--newstrending-boxinfeed -d-flex -j-center -ai-center">
#          <p>
#           <i class="icon icon-md icon-spinner icon-rotate">
#           </i>
#          </p>
#         </div>
#        </section>
#       </aside>
#      </div>
#     </div>
#    </div>
#    <div class="container-row">
#     <div class="row-content mb-0">
#      <nav class="col-12 m_breadcrumb" data-carousel-category="">
#       <ul class="container" itemscope="" itemtype="https://schema.org/BreadcrumbList">
#        <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#         <p>
#          <a href="/" itemprop="item">
#           <span itemprop="name">
#            Inicio
#           </span>
#          </a>
#          <i class="icon icon-sm icon-chevron-right-gray">
#          </i>
#         </p>
#         <meta content="1" itemprop="position"/>
#        </li>
#        <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#         <p>
#          <a href="/galicia" itemprop="item">
#           <span itemprop="name">
#            Galicia
#           </span>
#          </a>
#          <i class="icon icon-sm icon-chevron-right-gray">
#          </i>
#         </p>
#         <meta content="2" itemprop="position"/>
#        </li>
#        <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#         <p>
#          <a href="/a-coruna" itemprop="item">
#           <span itemprop="name">
#            Prov. de A Coruña
#           </span>
#          </a>
#          <i class="icon icon-sm icon-chevron-right-gray">
#          </i>
#         </p>
#         <meta content="3" itemprop="position"/>
#        </li>
#        <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#         <p>
#          <span itemprop="name">
#           A Coruña
#          </span>
#         </p>
#         <meta content="4" itemprop="position"/>
#        </li>
#       </ul>
#      </nav>
#     </div>
#    </div>
#   </div>
#   <elt-pre-footer class="elt-pre-footer" site="es">
#   </elt-pre-footer>
#   <elt-footer class="elt-footer" data-user="" site="es" user="">
#   </elt-footer>
#   <script type="text/javascript">
#    var cdn_url = "https://cdn.eltiempo.es";
# 	var cdn_static = "https://statics.eltiempo.es";
# 	var s3_cdn_url = "https://cdns3.eltiempo.es";
# 	var COUNTRY_CODE = "es";
# 	var SITE_NAME = "Eltiempo.es";
# 	var DEFAULT_COUNTRY = "es";
# 	var COUNTRY_COOKIE = "";
# 	var MAP_COUNTRY = "es";
# 	var SEARCH_URL = "/buscar";
# 	var DEFAULT_TEMP_UNIT = "c";
# 	var DEFAULT_WIND_UNIT = "kmh";
# 	var UNIT_LOCALES = {"kmh":"km\/h","km\/h":"km\/h","mph":"mph","ms":"m\/s","bf":"Bft","kt":"kt","c":"C","f":"F"};
#
#     var PAGE_RELOAD_SECONDS = "180";
#
#     var APPAPIURL = "https://www.eltiempo.es/api/v1/";
#     const APPAPIURLV2 = "https://api.eltiempo.es/api/v2/";
#     var APPURL = "https://www.eltiempo.es";
#     var SITEURLJS = "https://www.eltiempo.es";
#     var APPSITENAMEJS = "eltiempo";
#     var APPSITECOOKIE = ".eltiempo.es";
# 	var ADD_UNIT_VIDEO = "video-eltiempo.es";
#
# 		var AD_KEY_VALUES_STRING = "page_language%3Des%26body_id%3Dcity%26ab_testing_variant%3Ddefault%26foreca_id%3D103119841%26urlized%3Da-coruna%26poi_name%3DA%2520Coru%25C3%25B1a%26etcity_type%3Dcity%26continent%3DEUR%26country%3Des%26community%3Dgalicia%26weather_icon%3D100%26wind_speed%3D9%26region%3Da-coruna%26city_tab%3Dcity_days%26temp_c%3D19%26max_temp%3D%26clouds_level%3Dmostly-clear%26precip_amount%3Dnone%26precip_type%3Dnone%26pressure%3D1011.59996%26humidity%3D63%26uv_radiation%3D5%26nx_monday_weather_icon%3D210%26nx_monday_temp_average%3D65%26nx_tuesday_weather_icon%3D200%26nx_tuesday_temp_average%3D64%26nx_wednesday_weather_icon%3D410%26nx_wednesday_temp_average%3D60%26nx_thursday_weather_icon%3D220%26nx_thursday_temp_average%3D65%26nx_friday_weather_icon%3D200%26nx_friday_temp_average%3D59%26nx_saturday_weather_icon%3D200%26nx_saturday_temp_average%3D59%26nx_sunday_weather_icon%3D210%26nx_sunday_temp_average%3D62%26aqi%3Dgood%26no2%3Dgood%26so2%3Dgood%26o3%3Dgood%26pm25%3Dgood%26pm10%3Dgood%26co%3Dgood%26pollen_level%3Dnothing%26flu_info%3Dno%26group_name%3D";
# 	    // pss locale
#     var pss_locale = {
#     	'pss_rain':"Lluvia",
#     	'pss_snow':"Nieve",
#     	'pss_mix':"Aguanieve",
#     	'pss_without_precip':"Sin precip.",
#     	'pss_light':"Débil",
#     	'pss_moderate':"Moderado",
#     	'pss_heavy':"Fuerte",
#     	'pss_start_text':"Se esperan precipitaciones a las ",
#     	'pss_continue_text':"Continuarán las precipitaciones a las ",
#     	'pss_continue_no_stop_text':"Se esperan precipitaciones durante las próximas 3 horas.",
#     	'pss_continue_stop_text':"Las precipitaciones pararán a las ",
#     };
#
#     var statusAdPlayer = true;
#     var ctrlAdPlayerLaunched = false;
#   </script>
#   <script type="text/javascript">
#    if (typeof window.getCookie !== "undefined") {
#         var pv = getCookie('et_session_pv');
#         var cookieValue = "0";
#         if (pv !== null) {
#             var pvInt = parseInt(pv);
#             pvInt++;
#             cookieValue = pvInt.toString();
#         }
#         var now = new Date();
#         var expiration = new Date(now.getTime() + 12 * 3600 * 1000);
#         document.cookie = "et_session_pv" + "=" + cookieValue + "; path=/" + "; domain=" + COOKIE_DOMAIN_VISITOR + "; expires=" + expiration.toUTCString();
#
#         // if (typeof pageKeyValues !== "undefined") {
#         //     pageKeyValues["session_pv"] = cookieValue;
#         // }
#         //
#         // var additionalParams = "session_pv=" + cookieValue;
#         // if (typeof AD_KEY_VALUES_STRING !== "undefined") {
#         //     if (AD_KEY_VALUES_STRING.trim().length !== 0) {
#         //         AD_KEY_VALUES_STRING = AD_KEY_VALUES_STRING + encodeURIComponent("&" + additionalParams);
#         //     } else {
#         //         AD_KEY_VALUES_STRING = encodeURIComponent(additionalParams);
#         //     }
#         // }
#     }
#   </script>
#   <script defer="" src="https://cdn.eltiempo.es/dist/script.0fc05f770555d4f5dc6d0a2c729df55c.js">
#   </script>
#   <script>
#    /* '/js/isMobile.min.js' */
# (function () {var f={};var g=/iPhone/i,i=/iPod/i,j=/iPad/i,k=/\biOS-universal(?:.+)Mac\b/i,h=/\bAndroid(?:.+)Mobile\b/i,m=/Android/i,c=/(?:SD4930UR|\bSilk(?:.+)Mobile\b)/i,d=/Silk/i,b=/Windows Phone/i,n=/\bWindows(?:.+)ARM\b/i,p=/BlackBerry/i,q=/BB10/i,s=/Opera Mini/i,t=/\b(CriOS|Chrome)(?:.+)Mobile/i,u=/Mobile(?:.+)Firefox\b/i,v=function(l){return void 0!==l&&"MacIntel"===l.platform&&"number"==typeof l.maxTouchPoints&&l.maxTouchPoints>1&&"undefined"==typeof MSStream};function w(l){return function($){return $.test(l)}}function x(l){var $={userAgent:"",platform:"",maxTouchPoints:0};l||"undefined"==typeof navigator?"string"==typeof l?$.userAgent=l:l&&l.userAgent&&($={userAgent:l.userAgent,platform:l.platform,maxTouchPoints:l.maxTouchPoints||0}):$={userAgent:navigator.userAgent,platform:navigator.platform,maxTouchPoints:navigator.maxTouchPoints||0};var a=$.userAgent,e=a.split("[FBAN");void 0!==e[1]&&(a=e[0]),void 0!==(e=a.split("Twitter"))[1]&&(a=e[0]);var r=w(a),o={apple:{phone:r(g)&&!r(b),ipod:r(i),tablet:!r(g)&&(r(j)||v($))&&!r(b),universal:r(k),device:(r(g)||r(i)||r(j)||r(k)||v($))&&!r(b)},amazon:{phone:r(c),tablet:!r(c)&&r(d),device:r(c)||r(d)},android:{phone:!r(b)&&r(c)||!r(b)&&r(h),tablet:!r(b)&&!r(c)&&!r(h)&&(r(d)||r(m)),device:!r(b)&&(r(c)||r(d)||r(h)||r(m))||r(/\bokhttp\b/i)},windows:{phone:r(b),tablet:r(n),device:r(b)||r(n)},other:{blackberry:r(p),blackberry10:r(q),opera:r(s),firefox:r(u),chrome:r(t),device:r(p)||r(q)||r(s)||r(u)||r(t)},any:!1,phone:!1,tablet:!1};return o.any=o.apple.device||o.android.device||o.windows.device||o.other.device,o.phone=o.apple.phone||o.android.phone||o.windows.phone,o.tablet=o.apple.tablet||o.android.tablet||o.windows.tablet,o}f=x();if(typeof exports==="object"&&typeof module!=="undefined"){module.exports=f}else if(typeof define==="function"&&define.amd){define(function(){return f})}else{this["isMobile"]=f}})();
#   </script>
#   <!-- Add advertising configuration and out of page -->
#   <!-- Audience Collection Tag -->
#   <script data-vendor="iab:577" id="pandg-sdk-script" src="https://pghub.io/js/pandg-sdk.js" type="didomi/javascript">
#   </script>
#   <script data-vendor="iab:577" type="didomi/javascript">
#    document.querySelector('#pandg-sdk-script').addEventListener('load', function() {
#         var metadata = {
#             gdpr: {gdpr},
#             gdpr_consent: "{gdpr_consent}",
#             ccpa: null,
#             bp_id: "eltiempoes",
#         };
#
#         var config = {
#             name: "P&G",
#             pixelUrl: "https://pandg.tapad.com/tag"
#         };
#
#         var tagger = Tapad.init(metadata, config);
#         var data = {};
#         tagger.sync(data);
#     });
#   </script>
#   <!-- End AudienceScience Data Collection Tag -->
#   <script async="" src="https://cdn.eltiempo.es/dist/app.c5a400bbd192ef2eb3ab35e1d6dcfef1.js">
#   </script>
#   <!-- Add advertising and maps modules scripts -->
#   <script data-vendor="c:hotjar" type="didomi/javascript">
#    (function(h,o,t,j,a,r){
#         h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#         h._hjSettings={hjid:2171361,hjsv:6};
#         a=o.getElementsByTagName('head')[0];
#         r=o.createElement('script');r.async=1;
#         r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#         a.appendChild(r);
#     })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
#   </script>
#   <script data-vendor="iab:941" type="didomi/javascript">
#    (function(d,s,id,h,t){
#    var js,r,djs = d.getElementsByTagName(s)[0];
#    if (d.getElementById(id)) {return;}
#    js = d.createElement('script');js.id =id;js.async=1;
#    js.h=h;js.t=t;
#    r=encodeURI(btoa(d.referrer));
#    js.src="//"+h+"/pixel/js/"+t+"/"+r;
#    djs.parentNode.insertBefore(js, djs);
#   }(document, 'script', 'dogtrack-pixel','elti.spxl.socy.es', 'ELTI_832_828_090'));
#   </script>
#   <script async="" data-vendor="iab:596" src="https://cdn.insurads.com/bootstrap/H0RFGYQJ.js" type="didomi/javascript">
#   </script>
#   <script data-purposes="cookies,create_ads_profile" type="didomi/html">
#    <img src="https://engagefront.eltiempo.es/etpxl?tc_string={gdpr_consent}" width="1" height="1" border="0" />
#   </script>
#   <div id="appsflyer-placeholder">
#   </div>
#  </body>
#  <script>
#   function checkStatus() {
# 		const img = new Image();
# 		if (window.googletag && window.googletag.apiReady) {
# 			img.src = 'https://eco.eltiempo.es/echo.png?gpt=1&ts=' + new Date().getTime();
# 		} else {
# 			img.src = 'https://eco.eltiempo.es/echo.png?gpt=0&ts=' + new Date().getTime();
# 		}
# 	}
#
# 	setTimeout(checkStatus, 3000);
#  </script>
# </html>
#
# [OK] Respuesta HTTP recibida correctamente!

# %% [markdown]
# ### **Inspeccionar la página web**
#
# Al analizar la web vemos que todos los valores se encuentran en una tabla `<table>`.
#
# <img src = './img/inspeccion_tabla.jpg' width = 800>
#
# La tabla se encuentra dividida en dos partes: la cabezera `<thead>` y el cuerpo `<tbody>`.
#
# **Head**
#
# En la cabecera de la tabla podemos ver que aparece el día de la semana, la fecha, la temperatura máxima y la temperatura mínima de cada uno de los días, y todos se encuentran en una misma fila `<tr>`
#
# <img src = './img/inspeccion_head.jpg' width = 800>
#
# Si analizamos el contenido del `<tr>` vemos que aparecen una serie de etiquetas `<th>`. Cada una de ellas representa las columnas de la cabecera.
#
# En cada `<th>` aparecen los datos buscados.
#
# <img src = './img/inspeccion_columnas_head.jpg' width=800>

# %% [markdown]
# **Body**
#
# En la parte del body nos encontramos con las temperaturas para 08:00, 14:00 y 20:00 horas, así como la cantidad de lluvia, de nieve, el viento, la hora en que amanece y la hora en que anochece, para cada uno de los días. Cada una de ellas se encuentra en un `<tr>` diferente del body.
#
# Dentro de cada `<tr>` se encuentran una serie de etiquetas `<td>` que representan cada una de las columnas de la fila correspodiente. En ellas aparecen los atributos necesarios para hacer la extracción de datos.
#
# <img src = './img/inspeccion_filas_body.jpg' width = 800>

# %% [markdown]
# ### **Extracción de los datos**

# %% [markdown]
# Extraemos los datos del "head" y del "body" para poder manipular su contenido.

# %%
# obtener la tabla para poder tratar su contenido
print('[TASK] Analizando la tabla para obtener los valores actuales...')

# guardar los datos de la tabla indicando su clase
table = soup.find_all('table', attrs={'class': 'table'})[0]

# guardar el header de la tabla
head = table.thead
print('[OK] Valores del Head obtenidos correctamente')

# guardar el body de la tabla
body = table.tbody
print('[OK] Valores del Body obtenidos correctamente')
# Out:
# [TASK] Analizando la tabla para obtener los valores actuales...
# [OK] Valores del Head obtenidos correctamente
# [OK] Valores del Body obtenidos correctamente

# %% [markdown]
# Genero el archivo csv en el que voy a guardar los datos de la tabla y añado la cabecera.

# %%
# HEADER
keys=[keyword]

for h in range(0, 9):
    keys.append(head.find('tr').find_all(class_ = 'text-poppins-bold')[h].text.replace('\n                            ','').replace('\n                        ',''))
keys.append('Fecha_Creacion')

# genero el csv y agrego el header
print('[TASK] Añadiendo los nombres de las columnas al fichero CSV...')
append_header_as_row(
    file_name = 'clima-' + keyword + '.csv',
    field_names = keys
)
print('[OK] Valor añadido correctamente en el fichero CSV!')
# Out:
# [TASK] Añadiendo los nombres de las columnas al fichero CSV...
# [OK] Valor añadido correctamente en el fichero CSV!

# %% [markdown]
# Extraemos los datos de la cabecera: día de la semana, la fecha, la temperatura máxima y la temperatura mínima de cada uno de los días y los guardamos en un archivo csv.

# %%
# FECHA

print('[TASK] Analizando la tabla para obtener las fechas ...')
fecha=[]

fecha.append(head.find_all('tr')[0].find_all('th')[0].text)

for f in range(1, 10):
    fecha.append(
        head.find_all('tr')[0].find_all('th')[f].find(class_='text-roboto-condensed').text.replace('\n                                ','').replace('\n                            ','')
    )
    print('[OK] Valor encontrado correctamente!')
    
fecha.append(datetime.date.today())
dictionary = dict(zip(keys,fecha))
    
# Guardamos cada una de las filas generadas en el csv
print('[TASK] Añadiendo el nuevo valor al fichero CSV...')
append_dict_as_row(
    file_name = 'clima-' + keyword + '.csv', 
    dict_of_elem = dictionary, # diccionario de valores
    field_names = keys   # nombres de las columnas     
)
print('[OK] Valor añadido correctamente en el fichero CSV!')

# TEMPERATURA MÁXIMA

print('[TASK] Analizando la tabla para obtener las temperaturas máximas ...')
tmaxima=[]

tmaxima.append(head.find_all('tr')[0].find_all('th')[0].text)

for tmax in range(1, 10):
    tmaxima.append(
        head.find_all('tr')[0].find_all('th')[tmax].find_all(class_='degrees')[0].text
    )
    print('[OK] Valor encontrado correctamente!')
    
tmaxima.append(datetime.date.today())
dictionary = dict(zip(keys,tmaxima))
    
# Guardamos cada una de las filas generadas en el csv
print('[TASK] Añadiendo el nuevo valor al fichero CSV...')
append_dict_as_row(
    file_name = 'clima-' + keyword + '.csv', 
    dict_of_elem = dictionary, # diccionario de valores
    field_names = keys   # nombres de las columnas     
)
print('[OK] Valor añadido correctamente en el fichero CSV!')

# TEMPERATURA MÍNIMA

print('[TASK] Analizando la tabla para obtener las temperaturas mínimas ...')

tminima=[]

tminima.append(head.find_all('tr')[0].find_all('th')[0].text)

for tmin in range(1, 10):
    tminima.append(
        head.find_all('tr')[0].find_all('th')[tmin].find_all(class_='degrees')[1].text
    )
    print('[OK] Valor encontrado correctamente!')
    
tminima.append(datetime.date.today())
dictionary = dict(zip(keys,tminima))
    
# Guardamos cada una de las filas generadas en el csv
print('[TASK] Añadiendo el nuevo valor al fichero CSV...')
append_dict_as_row(
    file_name = 'clima-' + keyword + '.csv', 
    dict_of_elem = dictionary, # diccionario de valores
    field_names = keys   # nombres de las columnas     
)
print('[OK] Valor añadido correctamente en el fichero CSV!')
# Out:
# [TASK] Analizando la tabla para obtener las fechas ...
# [OK] Valor encontrado correctamente!
# [OK] Valor encontrado correctamente!
# [OK] Valor encontrado correctamente!
# [OK] Valor encontrado correctamente!
# [OK] Valor encontrado correctamente!
# [OK] Valor encontrado correctamente!
# [OK] Valor encontrado correctamente!
# [OK] Valor encontrado correctamente!
# [OK] Valor encontrado correctamente!
# [TASK] Añadiendo el nuevo valor al fichero CSV...
# [OK] Valor añadido correctamente en el fichero CSV!
# [TASK] Analizando la tabla para obtener las temperaturas máximas ...
# [OK] Valor encontrado correctamente!
# [OK] Valor encontrado correctamente!
# [OK] Valor encontrado correctamente!
# [OK] Valor encontrado correctamente!
# [OK] Valor encontrado correctamente!
# [OK] Valor encontrado correctamente!
# [OK] Valor encontrado correctamente!
# [OK] Valor encontrado correctamente!
# [OK] Valor encontrado correctamente!
# [TASK] Añadiendo el nuevo valor al fichero CSV...
# [OK] Valor añadido correctamente en el fichero CSV!
# [TASK] Analizando la tabla para obtener las temperaturas mínimas ...
# [OK] Valor encontrado correctamente!
# [OK] Valor encontrado correctamente!
# [OK] Valor encontrado correctamente!
# [OK] Valor encontrado correctamente!
# [OK] Valor encontrado correctamente!
# [OK] Valor encontrado correctamente!
# [OK] Valor encontrado correctamente!
# [OK] Valor encontrado correctamente!
# [OK] Valor encontrado correctamente!
# [TASK] Añadiendo el nuevo valor al fichero CSV...
# [OK] Valor añadido correctamente en el fichero CSV!

# %% [markdown]
# Extraemos los datos del body: temperaturas a las 08:00, 14:00 y 20:00; las precipitaciones de lluvia y nieve; la velocidad del viento, la hora en que amanece y en que anochece y los guardamos en el archivo csv.

# %%
# TEMPERATURAS A LAS 08:00, 14:00 Y 20:00
# cada 'tr' representa una fila
# cada 'td' representa una columna

print('[TASK] Analizando la tabla para obtener las temperaturas ...')

for row in range(0,3):

    temperaturas=[]

    temperaturas.append(body.find_all('tr')[row].find_all('td')[0].text)
    try:
        temperaturas.append(body.find_all('tr')[row].find_all('td')[1].find_all(class_='degrees')[0].text) # segunda columna
    except:
        temperaturas.append(body.find_all('tr')[row].find_all('td')[1].text.replace('\n',''))

    for col in range(2,10):
        temperaturas.append(body.find_all('tr')[row].find_all('td')[col].find_all(class_='degrees')[0].text.replace('\n',''))

    temperaturas.append(datetime.date.today())

    print('[OK] Valor encontrado correctamente!')
        
    # creamos el diccionario que exportaremos al csv
    dictionary = dict(zip(keys,temperaturas))
        
    # Guardamos cada una de las filas generadas en el csv
    print('[TASK] Añadiendo el nuevo valor al fichero CSV...')
    append_dict_as_row(
        file_name = 'clima-' + keyword + '.csv', 
        dict_of_elem = dictionary, # diccionario de valores
        field_names = keys   # nombres de las columnas     
    )
    print('[OK] Valor añadido correctamente en el fichero CSV!')

# LLUVIA Y NIEVE

print('[TASK] Analizando la tabla para obtener las precipitaciones de lluvia y nieve ...')

for rain in range(3,5):
    
    lluvia = []
    
    for col in range(0, 10):
        lluvia.append(body.find_all('tr')[rain].find_all('td')[col].text)
        
    lluvia.append(datetime.date.today())

    print('[OK] Valor encontrado correctamente!')
        
    # creamos el diccionario que exportaremos al csv
    dictionary = dict(zip(keys,lluvia))
        
    # Guardamos cada una de las filas generadas en el csv
    print('[TASK] Añadiendo el nuevo valor al fichero CSV...')
    append_dict_as_row(
        file_name = 'clima-' + keyword + '.csv', 
        dict_of_elem = dictionary, # diccionario de valores
        field_names = keys   # nombres de las columnas     
    )
    print('[OK] Valor añadido correctamente en el fichero CSV!')  
    
# VIENTO

print('[TASK] Analizando la tabla para obtener la velocidad del viento ...')

viento = []

viento.append(body.find_all('tr')[5].find_all('td')[0].text)

for col in range(1,10):
    viento.append(body.find_all('tr')[5].find_all('td')[col].find(class_='wind-text-value').text + ' ' + body.find_all('tr')[5].find_all('td')[col].find(class_='wind-text-unit').text)
    
viento.append(datetime.date.today())

print('[OK] Valor encontrado correctamente!')
        
# creamos el diccionario que exportaremos al csv
dictionary = dict(zip(keys,viento))
        
# Guardamos cada una de las filas generadas en el csv
print('[TASK] Añadiendo el nuevo valor al fichero CSV...')
append_dict_as_row(
    file_name = 'clima-' + keyword + '.csv', 
    dict_of_elem = dictionary, # diccionario de valores
    field_names = keys   # nombres de las columnas     
)
print('[OK] Valor añadido correctamente en el fichero CSV!')

# HORA AMANECER Y ANOCHECER

print('[TASK] Analizando la tabla para obtener las horas de amanecer y anochecer ...')

for sol in range(6,8):
    
    luz = []
    
    for col in range(0, 10):
        luz.append(body.find_all('tr')[sol].find_all('td')[col].text)
        
    luz.append(datetime.date.today())

    print('[OK] Valor encontrado correctamente!')
        
    # creamos el diccionario que exportaremos al csv
    dictionary = dict(zip(keys,luz))
        
    # Guardamos cada una de las filas generadas en el csv
    print('[TASK] Añadiendo el nuevo valor al fichero CSV...')
    append_dict_as_row(
        file_name = 'clima-' + keyword + '.csv', 
        dict_of_elem = dictionary, # diccionario de valores
        field_names = keys   # nombres de las columnas     
    )
    print('[OK] Valor añadido correctamente en el fichero CSV!')
# Out:
# [TASK] Analizando la tabla para obtener las temperaturas ...
# [OK] Valor encontrado correctamente!
# [TASK] Añadiendo el nuevo valor al fichero CSV...
# [OK] Valor añadido correctamente en el fichero CSV!
# [OK] Valor encontrado correctamente!
# [TASK] Añadiendo el nuevo valor al fichero CSV...
# [OK] Valor añadido correctamente en el fichero CSV!
# [OK] Valor encontrado correctamente!
# [TASK] Añadiendo el nuevo valor al fichero CSV...
# [OK] Valor añadido correctamente en el fichero CSV!
# [TASK] Analizando la tabla para obtener las precipitaciones de lluvia y nieve ...
# [OK] Valor encontrado correctamente!
# [TASK] Añadiendo el nuevo valor al fichero CSV...
# [OK] Valor añadido correctamente en el fichero CSV!
# [OK] Valor encontrado correctamente!
# [TASK] Añadiendo el nuevo valor al fichero CSV...
# [OK] Valor añadido correctamente en el fichero CSV!
# [TASK] Analizando la tabla para obtener la velocidad del viento ...
# [OK] Valor encontrado correctamente!
# [TASK] Añadiendo el nuevo valor al fichero CSV...
# [OK] Valor añadido correctamente en el fichero CSV!
# [TASK] Analizando la tabla para obtener las horas de amanecer y anochecer ...
# [OK] Valor encontrado correctamente!
# [TASK] Añadiendo el nuevo valor al fichero CSV...
# [OK] Valor añadido correctamente en el fichero CSV!
# [OK] Valor encontrado correctamente!
# [TASK] Añadiendo el nuevo valor al fichero CSV...
# [OK] Valor añadido correctamente en el fichero CSV!

# %% [markdown]
# ### **Cargamos el csv en un DataFrame**

# %% [markdown]
# Utilizando la librería de Pandas, cargamos el archivo csv creado en un DataFrame para poder visualizar la tabla con los datos obtenidos.

# %%
df = pd.read_csv('clima-' + keyword + '.csv')

# Poner nombre a las filas incompletas
df.iloc[0,0] = 'Fecha'
df.iloc[1,0] = 'Tmax'
df.iloc[2,0] = 'Tmin'
df.iloc[9,0] = 'Amanecer'
df.iloc[10,0] = 'Anochecer'
df
# Out:
#      a-coruna      Hoy      Mañ      Lun      Mar      Mié      Jue      Vie  \
# 0       Fecha    7 SEP    8 SEP    9 SEP   10 SEP   11 SEP   12 SEP   13 SEP
# 1        Tmax      21°      21°      20°      20°      20°      19°      19°
# 2        Tmin      14°      14°      16°      15°      15°      16°      15°
# 3       08:00      NaN      16°      18°      17°      15°      17°      15°
# 4       14:00      21°      21°      20°      20°      20°      19°      19°
# 5       20:00      19°      20°      19°      18°      18°      17°      17°
# 6      Lluvia     0 mm   1.1 mm   0.4 mm     0 mm   2.2 mm   4.4 mm     0 mm
# 7       Nieve     0 cm     0 cm     0 cm     0 cm     0 cm     0 cm     0 cm
# 8      Viento  14 km/h  14 km/h  17 km/h  22 km/h  14 km/h  14 km/h  15 km/h
# 9    Amanecer    08:03    08:04    08:05    08:06    08:07    08:08    08:10
# 10  Anochecer    20:59    20:57    20:55    20:54    20:52    20:50    20:48
#
#         Sáb      Dom Fecha_Creacion
# 0    14 SEP   15 SEP     2024-09-07
# 1       21°      21°     2024-09-07
# 2       14°      15°     2024-09-07
# 3       14°      15°     2024-09-07
# 4       21°      21°     2024-09-07
# 5       19°      19°     2024-09-07
# 6      0 mm     0 mm     2024-09-07
# 7      0 cm     0 cm     2024-09-07
# 8   14 km/h  14 km/h     2024-09-07
# 9     08:11    08:12     2024-09-07
# 10    20:46    20:44     2024-09-07

# %% [markdown]
# Como podéis apreciar hay un NaN a las 08:00 horas del día de Hoy; eso es debido a que el código se ejecutó entre las 08:00 y las 14:00 horas. Si el código se ejecuta entre las 14:00 y las 20:00 horas, aparecerá un NaN también a las 14:00 horas. Si el código se ejecuta después de las 20:00 horas, la columna "Hoy" ya no estará disponible y empezará la tabla en "Mañana".

# %% [markdown]
# ### **Conclusión**

# %% [markdown]
# Una de las combinaciones más comunes en web scraping es usar "requests" para obtener el contenido HTML de una página web y luego usar "BeautifulSoup" para analizar y extraer la información deseada de ese contenido. Ambas bibliotecas juntas son muy poderosas para realizar dichas tareas.
#
# En este artículo hemos visto cómo podemos extraer los datos climáticos de los próximos 9 días de una localidad de España, aunque podríamos utilizar el mismo código para obtener los de cualquier localidad, simplemente con cambiar el contenido de la variable "keyword".

# %% [markdown]
# ### **Referencias**
#
# - [Python](https://www.python.org/)
# - [Ipykernel](https://pypi.org/project/ipykernel/)
# - [tqdm](https://pypi.org/project/tqdm/)
# - [joblib](https://pypi.org/project/joblib/)
# - [Pandas](https://pandas.pydata.org/)
# - [Requests](https://pypi.org/project/requests/)
# - [BeautifulSoup](https://pypi.org/project/beautifulsoup4/)
